# %% [markdown]
# <a href="https://colab.research.google.com/github/JorL-08/git-y-github-desde-google-colab/blob/main/Pruebas_git_github_googlecolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hola mundo")
# Out:
# Hola mundo

# %%
# !git config --global user.name "jorge_google"
# !git config --global user.email "jorge.saenz147@gmail.com"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Crear datos de prueba
data = {
    'Mes': ['Ene', 'Feb', 'Mar', 'Abr', 'May'],
    'Ventas': [150, 200, 180, 250, 210]
}
df = pd.DataFrame(data)

# 2. Mostrar resumen
print("Resumen de ventas:")
print(df.describe())

# 3. Graficar
plt.plot(df['Mes'], df['Ventas'], marker='o', color='skyblue')
plt.title('Evolución de Ventas - Prueba GitHub')
plt.show()
# Out:
# Resumen de ventas:
#            Ventas
# count    5.000000
# mean   198.000000
# std     37.013511
# min    150.000000
# 25%    180.000000
# 50%    200.000000
# 75%    210.000000
# max    250.000000
